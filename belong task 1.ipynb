# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#os.getcwd()

data_dir = "D:\dataset"

# %%
catagories = ['5-10', '11-15','16-18', '19-25', '26-30', '31-40', '41-52', '53-62', '63-78']
for catagory in catagories:
    path = os.path.join(data_dir, catagory)
    for img in os.listdir(path):
        image_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(image_array, cmap = "gray")
        plt.show()
        break
    break

# %%
print(image_array)
# Out:
# [[ 98 104  81 ... 166 166 166]
#  [101  97  71 ... 165 166 166]
#  [103  87  59 ... 165 165 166]
#  ...
#  [ 66  79  86 ...  70  65  55]
#  [ 68  83  89 ...  73  67  56]
#  [ 69  85  91 ...  75  70  57]]

# %%
IMG_SIZE = 90
new_array = cv2.resize(image_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap = 'gray')
plt.show()
